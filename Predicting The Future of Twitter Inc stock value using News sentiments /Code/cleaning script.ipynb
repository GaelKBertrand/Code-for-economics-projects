# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
df= pd.read_pickle("/content/drive/MyDrive/Merged_New_+1_Twitter Processed Text with Time and Sentiments_Fresh.pkl")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179 entries, 0 to 178
# Data columns (total 16 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Time                                          179 non-null    object
#  1   Date                                          179 non-null    object
#  2   News source                                   179 non-null    object
#  3   Title                                         179 non-null    object
#  4   Description                                   179 non-null    object
#  5   index                                         179 non-null    int64
#  6   timestamp                                     179 non-null    float64
#  7   uid                                           179 non-null    object
#  8   url                                           179 non-null    object
# ...

# %% [markdown]
# cleaning

# %%
df= df[df["Stock Prices"].notna()]
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 134 entries, 4 to 177
# Data columns (total 16 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Time                                          134 non-null    object
#  1   Date                                          134 non-null    object
#  2   News source                                   134 non-null    object
#  3   Title                                         134 non-null    object
#  4   Description                                   134 non-null    object
#  5   index                                         134 non-null    int64
#  6   timestamp                                     134 non-null    float64
#  7   uid                                           134 non-null    object
#  8   url                                           134 non-null    object
# ...

# %%
df['Stock'].replace('', np.nan, inplace=True)

# %%
df.dropna(subset=['Stock'], inplace=True)

# %%
df.shape

# %% [markdown]
# Saving

# %%
df.rename(columns = {'Stock Prices':'Stock'}, inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 134 entries, 4 to 177
# Data columns (total 16 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Time                                          134 non-null    object
#  1   Date                                          134 non-null    object
#  2   News source                                   134 non-null    object
#  3   Title                                         134 non-null    object
#  4   Description                                   134 non-null    object
#  5   index                                         134 non-null    int64
#  6   timestamp                                     134 non-null    float64
#  7   uid                                           134 non-null    object
#  8   url                                           134 non-null    object
# ...

# %%
df.to_csv('/content/drive/MyDrive/Stock+Sentiment_Twitter.csv')

# %%
df.to_pickle('/content/drive/MyDrive/Stock+Sentiment_Twitter.pkl')
